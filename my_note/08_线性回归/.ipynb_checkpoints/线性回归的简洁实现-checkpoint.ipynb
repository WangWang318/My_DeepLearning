# %%
import numpy as np
import torch
from torch.utils import data
from d2l import torch as d2l

# %%
true_w = torch.tensor([2., -3.4])
true_b = 4.2
features, labels = d2l.synthetic_data(true_w, true_b, 1000)

# %%
# 如何查
d2l.synthetic_data?

# %%
d2l.synthetic_data??

# %%
def load_array(data_arrays, batch_size, is_train=True):  #@save
    """构造一个PyTorch数据迭代器"""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)

batch_size = 10
data_iter = load_array((features, labels), batch_size)
# iter(data_iter)
next(iter(data_iter))
# Out:
# [tensor([[-1.1047, -0.0249],
#          [ 1.0362,  0.4408],
#          [-0.7301, -0.4625],
#          [-1.1386, -0.2962],
#          [ 0.6002,  0.7436],
#          [-0.0622, -0.6774],
#          [-0.5674,  0.4543],
#          [ 0.7054,  1.3291],
#          [ 1.7371, -1.3568],
#          [ 1.6749,  0.4384]]),
#  tensor([[ 2.0699],
#          [ 4.7768],
#          [ 4.3132],
#          [ 2.9235],
#          [ 2.8802],
#          [ 6.3822],
#          [ 1.5097],
#          [ 1.1034],
#          [12.2918],
#          [ 6.0644]])]

# %% [markdown]
# ![b96b1428adb74e8e8facb79e7293cb3b.png](attachment:b96b1428adb74e8e8facb79e7293cb3b.png)

# %% [markdown]
# ![6cef4473771341508931a75977a0b3ae.png](attachment:6cef4473771341508931a75977a0b3ae.png)

# %%
from torch import nn # 神经网络的缩写
net = nn.Sequential(nn.Linear(2,1)) # 输入维度是2，输出维度是1
# sequential 容器

# %%
net[0].weight.data.normal_(0, 0.01)
net[0].bias.data.fill_(0)
# Out:
# tensor([0.])

# %%
net
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
net[0]
# Out:
# Linear(in_features=2, out_features=1, bias=True)

# %%
loss = nn.MSELoss()

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.03)

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X, y in data_iter:
        l = loss(net(X) ,y) # loss
        trainer.zero_grad() # 优化器梯度清零
        l.backward() # 反向梯度
        trainer.step() # 模型更新参数w,b
    l = loss(net(features), labels)
    print(f'epoch {epoch + 1}, loss {l:f}')
# Out:
# epoch 1, loss 0.000105
# epoch 2, loss 0.000105
# epoch 3, loss 0.000106
